# %%
import nltk
import numpy as np
import os
import random
import sys

from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop

# %%
# Download NLTK model data (you need to do this once)
nltk.download("book")

# %%
corpora_dir = "/Users/Ajay/nltk_data/corpora/state_union"

# Read all file paths in corpora directory
file_list = []
for root, _ , files in os.walk(corpora_dir):  
    for filename in files:
        file_list.append(os.path.join(root, filename))
        
print("Read ", len(file_list), " files..." )

# Extract text from all documents
docs = []

for files in file_list:
    with open(files, 'r') as fin:
        try:
            str_form = fin.read().lower().replace('\n', '')
            docs.append(str_form)
        except UnicodeDecodeError: 
            # Some sentences have wierd characters. Ignore them for now
            pass
# Combine them all into a string of text
text = ' '.join(docs)

print('corpus length:', len(text))
# Out:
# Read  66  files...
# corpus length: 1915949

# %%
chars = sorted(list(set(text)))
print('Total Number of Unique Characters:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars)) # Character to index
indices_char = dict((i, c) for i, c in enumerate(chars)) # Index to Character
# Out:
# Total Number of Unique Characters: 57

# %%
"""
Recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
"""

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40 # Number of characters considered
step = 3 # Stide of our window
sentences = []
next_chars = []

# Rading the text in terms of sequence of characters
# Extract only 'maxlen' characters every time
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    # The character just after the sequence is the label
    next_chars.append(text[i + maxlen]) 
print('nb sequences:', len(sentences))

print('Vectorization...')
# Initializing Tensor (training data)
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool) 
# Initializing Output that holds next character (label)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool) 
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        # Populate Tensor Input
        x[i, t, char_indices[char]] = 1 
    # Populate y with the character just after the sequence
    y[i, char_indices[next_chars[i]]] = 1


def sample(preds, temperature=1.0):
    """Perform Temperature Sampling"""
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature 
    exp_preds = np.exp(preds)
    # Softmax of predictions
    preds = exp_preds / np.sum(exp_preds) 
    # Sample a single characters, with probabilities defined in `preds`
    probas = np.random.multinomial(1, preds, 1) 
    return np.argmax(probas)


def on_epoch_end(epoch, _):
    """Function invoked at end of each epoch. Prints generated text"""
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- Diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            # Generate next character
            next_index = sample(preds, diversity) 
            next_char = indices_char[next_index]
            
            # Append character to generated sequence
            generated += next_char 
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
    
    # Save model weights into file
    model.save_weights('saved_weights.hdf5', overwrite=True)
        

# After every single epoch, we are going to call the function on_epoch_end
# to generate some text.
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
print('Building model...')
# Size of vector in the hidden layer.
hidden_size = 128 
# Initialize Sequential Model
model = Sequential()
model.add(LSTM(hidden_size, input_shape=(maxlen, len(chars))))
# Add the output layer that is a softmax of the number of characters
model.add(Dense(len(chars), activation='softmax')) 
# Optimization through RMSprop
optimizer_new = RMSprop() 
# Consider cross Entropy loss. Why? MLE of P(D | theta)
model.compile(loss='categorical_crossentropy', optimizer=optimizer_new) 

# Train this for 30 epochs. Size of output from LSTM i.e. hidden layer vector shape=128
model.fit(x, y,
          batch_size=128,
          epochs=30,
          callbacks=[print_callback, checkpointer])
# Out:
# Building model...
# Epoch 1/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 2.0907
# ----- Generating text after Epoch: 0
# ----- Diversity: 0.2
# ----- Generating with seed: "with national security. we have held our"
# with national security. we have held our commentical security and the streng and the were of the program of the state and the prost and the congress of the world the streng the for the wark to prople to the program the proples and the program of the sompersion of the program of the rest and the congress of the will the provice the streng the program in the with the proples and the will our a belical and the for the proples and the were
# ----- Diversity: 0.5
# ----- Generating with seed: "with national security. we have held our"
# with national security. we have held our cansion of the secolical seacly councress the force a for the will nater and the congress of cat of the faith of the state you start bection and to conting expenting the progras consicitions in which for is in congress the hand be to mist maring the free in the wars strentic and the have to assical and in the congiturics a allies. wo lo this of the promed the the more and the a freesed the prople
# ----- Diversity: 1.0
# ----- Generating with seed: "with national security. we have held our"
# with national security. we have held our ropporatiog texthingsien lagerencadiet. issippeace and to is of misuin that contincing sowe that bus  ourland.fer tied statity lece prourt with that fricinion, the figh and.we ting becaus of our for the plebules of the wall besulaters for groar, for thos issment jore misivit rators fou shourgy seclise tonies prticilitiand be that are amsutiy and the conctel an ar credats projustust instandee ligs
# ----- Diversity: 1.2
# ----- Generating with seed: "with national security. we have held our"
# with national security. we have held our ginemins dedsoriky oflly coung endyem of fuyding ans modp bequest of tiss-aimitions batkic dmfctoruquers - is lastrimuk woildsnan, modncessal to lival wechable. need in alfaidcenally agrissidnit of the than chic8 eeforss of pirsalien. in eromting this prosove the shates in chilurcour c9nghit, and doilst yighen artey--thamm for maks.ry, an follgre wermcan stctessure years. of efoll yad, molbiag, o
# 638637/638637 [==============================] - 656s 1ms/step - loss: 2.0907
# /Users/Ajay/anaconda/lib/python3.6/site-packages/keras/callbacks.py:406: RuntimeWarning: Can save best model only with val_loss available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# Epoch 2/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.6366
# ----- Generating text after Epoch: 1
# ----- Diversity: 0.2
# ----- Generating with seed: "ruction and development for all the peop"
# ruction and development for all the people and the enery of the states and to the states to the endory and the states of the insternst and the enery of the congress of the perion of the world states and the new to the enery of the states and the states of the enery and the states of the world and contrints to the congress of the congress of the security to the entorical people of the eneromment and the security of the congress of the un
# ----- Diversity: 0.5
# ----- Generating with seed: "ruction and development for all the peop"
# ruction and development for all the people to worker past in the sount a states in to mest and the gongress to the nation of the assictation in the past the workers of our not the union and workers, the more community resourcest consurty to the this country being the resure to the tades of the congress of the entory possible to the stall put in the unition will searth and the congress of the sourted the collerar agreached more should pr
# ----- Diversity: 1.0
# ----- Generating with seed: "ruction and development for all the peop"
# ruction and development for all the people. it must make and exciitienal facition year we tax labes. which wouds'stingty consuation. to contred of paip ablies, to int mime that headors on their great tentot and carte of at the now trankens wal, as soumcher, my sand clualicn whoreaking, westhal to be propoted us fille--ay hourd will to the that cill ot is oper de contriving spending musuing the year, alloody. it they experceded to go ent
# ----- Diversity: 1.2
# ----- Generating with seed: "ruction and development for all the peop"
# ruction and development for all the people to all, ton re we hich taxean headerting them0nicy, in wheet prouder.the conture is all in osr ollesed'll hound other plicasion. lust borks nceedias of lengers wolling. to pupportint aperments on gan of force ty america ade those woud the nefershation as gilons. thriad howe8, aironse yi hiake us foutdeen thas milition for theses, thoshevels butrets conficent us their for ster to in our to may a
# 638637/638637 [==============================] - 814s 1ms/step - loss: 1.6366
# Epoch 3/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.4799
# ----- Generating text after Epoch: 2
# ----- Diversity: 0.2
# ----- Generating with seed: "and fires, and they'll tell you that. go"
# and fires, and they'll tell you that. government the form the congress and the congress of the security of the world a consider the world a security of the world and the program to the congress of the defense and the country and the congress of the security of the congress of the security of the world as security of the congress of the congress and the congress and the congress to the program to the congress to the congress and the secu
# ----- Diversity: 0.5
# ----- Generating with seed: "and fires, and they'll tell you that. go"
# and fires, and they'll tell you that. government the defense in the enterment of is inflation in the degation that we have the free of the latt of the expersed to the administration of the future of the to great the congress stand country for i amorica sack and the mones of the congress to the most american past for america which have president and the program in a light to the proposed the the values of our enterment in the congress an
# ----- Diversity: 1.0
# ----- Generating with seed: "and fires, and they'll tell you that. go"
# and fires, and they'll tell you that. god a beders to expand on the freedon libtures, irach lasor, ancreasifible enceroums be sove new industrial security and improved minisan ling-agringthence se we made than endage was in renest ask go well-a. i cain to you works of the demacress. security, government at the naod 18tellds in wher americas be in a remaid in present to america must enorg. the civil school of the bear this that their gen
# ----- Diversity: 1.2
# ----- Generating with seed: "and fires, and they'll tell you that. go"
# and fires, and they'll tell you that. governfrims, d. inamities.- to much is that ghing. y hivery marketsan lonkle enfice to kerut our reiced to still edois, it how ideiks for now, have being mounth to mutt epportand income thio of commistudets and go furaty as an the casps, haping suchers, this years have relasingatly edoint our urroms and our edfected maipted and proff grouss eable oncieal processen a kear mode in feal own thembarten
# 638637/638637 [==============================] - 762s 1ms/step - loss: 1.4799
# Epoch 4/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.3957
# ----- Generating text after Epoch: 3
# ----- Diversity: 0.2
# ----- Generating with seed: " not want to be the president who built "
#  not want to be the president who built the security of the congress to the state of the family and the resources in the congress to the world of the family for the world of the constitutions of the family in the american for the world of the family development that we seek a so that the congress and the family and the congress and the congress to the congress of the world of the people and the people and the world and the family and th
# ----- Diversity: 0.5
# ----- Generating with seed: " not want to be the president who built "
#  not want to be the president who built the family. we should not the world. it is strong that we deen the sestable for the family and still afrucimical adversest of the farm in the peace and the senter the advinage in the fiscal year to is all well in providing such constitutions and the communities and invest and well are that we are all we see the commentance of every of the basic federal government to our peace on the fiscal year an
# ----- Diversity: 1.0
# ----- Generating with seed: " not want to be the president who built "
#  not want to be the president who built to the extension. see athout back if their country have abilities -- yet us the may ou to lige a togething we leads dorated fire will seve fiscimy for rights withdistan inctaited our boord to iraus unioning your overeage, the to this beat throughout could joints depants, we are futwal i will so indledection has government degiss to our need. and siminse to those a fexted is now in the gape they, a
# ----- Diversity: 1.2
# ----- Generating with seed: " not want to be the president who built "
#  not want to be the president who built enewgically, angernualionals intansubirs the distivignation, we stall othered makity its to give of turnee sevengion, nnurwere, raves and phaip is distondat, recentruess and who past for amorica-ies. (applause.) hellef't agsted moy and full goo you hi fine--tasistic century effictinusthor's nowow what interints is drack. i fane form good thetrrach. feright will establited bairs. but to relady pasi
# 638637/638637 [==============================] - 697s 1ms/step - loss: 1.3956
# Epoch 5/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.3431
# ----- Generating text after Epoch: 4
# ----- Diversity: 0.2
# ----- Generating with seed: "ter consequences of more than three cent"
# ter consequences of more than three century for the security of the peace and the state of the free of the security of the congress than the lives of the world of the peace of the fact of the security of the security of the some of the security of the security and the problem of the security of the world of the security of the family of the free of the forces of the basic of the state of the congress to the congress to the security of t
# ----- Diversity: 0.5
# ----- Generating with seed: "ter consequences of more than three cent"
# ter consequences of more than three central a strong and the world, and and and stable the way to provide freedom and the postally and resources will be in so many to the program on the world. we should be made the americans without all the people and women they are problem and expenditures of the congress depend to the world and the later states of the federal action of the future of our national and states, now that you will be expend
# ----- Diversity: 1.0
# ----- Generating with seed: "ter consequences of more than three cent"
# ter consequences of more than three centual afeary people, butinesss.it presence--by mangers we heaping a world. keep vivole i values convicted, cally lost contrisement congress. we have will as a unsure our handlanst, from to thten our great processitiantay. eurape man and control commencaing thir beyenses are cavilo of our health can pled as a must we need, i cannatially. re modern confis and communities. is statue. in re-share ow as
# ----- Diversity: 1.2
# ----- Generating with seed: "ter consequences of more than three cent"
# ter consequences of more than three centuur on scalls thmich criditayly leos believe bewoldning who are solve taking stanhter thir de1bly against hulf-retere for, crutice from it. your cirits, eppolting our economy higher dollors as a0ghting tax credsts, in this dutuil people fanish, all world upder.for the presidents which will this progrems and prosperity.we cansold-bat buindal livess we have reductionaty greated nnext they will unnea
# 638637/638637 [==============================] - 751s 1ms/step - loss: 1.3431
# Epoch 6/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.3074
# ----- Generating text after Epoch: 5
# ----- Diversity: 0.2
# ----- Generating with seed: "sent back to their homes or sent to hide"
# sent back to their homes or sent to hide the congress to the congress to the people and the people of the free sold and our program of the security of the people of the people of the people of the people of the family and our states and the family to the first a congress to the congress to the congress and the congress and the people of the many of the congress and the state of the congress to the congress and defense of the people of t
# ----- Diversity: 0.5
# ----- Generating with seed: "sent back to their homes or sent to hide"
# sent back to their homes or sent to hide to strengthen and the congress -- i can be as a support goal recession of the world, i should you to the most in the united states for a strong of substantial a community of the people. the security of the because of the future of the policies is our to detering means to federal to a nation for the past years of the first for the president second will be and political security of the congress and
# ----- Diversity: 1.0
# ----- Generating with seed: "sent back to their homes or sent to hide"
# sent back to their homes or sent to hide conditution loses, the farthing for olwnor call of a serse price and gormuction to fest once america,s ald destably -- we have a world of oid the more retirsted subsuring ever the saccial years: we skegil all impressistacks and delasings, i change to drea teganisom, and our unemse for our country canchural country, the laid, leves. eleded on our energy to this congress is shar all the united say
# ----- Diversity: 1.2
# ----- Generating with seed: "sent back to their homes or sent to hide"
# sent back to their homes or sent to hide a;beatoning world, and about tho future. to be providence. labor. adequate. our own, a supfes amertment basbed economic parties world bet would be larger oud school discrigr force agestical president employment, to the right and balanced trobom. but year is my haid tockers which do i huppote the college of aprivising uni. tofallys'fancess retrommentment than turn offers. eified onligally just dol
# 638637/638637 [==============================] - 740s 1ms/step - loss: 1.3074
# Epoch 7/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.2811
# ----- Generating text after Epoch: 6
# ----- Diversity: 0.2
# ----- Generating with seed: " shortage of qualified federal judges an"
#  shortage of qualified federal judges and state of the states and state of the end of the world. we are not so that we can be provides for the state of the world and the congress to provide the congress to the progress to provide the state of the state of the world and the congress to the progress to the congress and state of the state of the congress to the congress to the congress to come the state of the national programs and the con
# ----- Diversity: 0.5
# ----- Generating with seed: " shortage of qualified federal judges an"
#  shortage of qualified federal judges and stable good states and the congress and recent responsibility to seek to the congress to convern the congress and providing means and the needs of the real continuing activities and we have the armed a that we will ask to expendetween and the americans and the congress of our national resources common progress to the solvices in the protect and other the world as one congress to support the stre
# ----- Diversity: 1.0
# ----- Generating with seed: " shortage of qualified federal judges an"
#  shortage of qualified federal judges and vital neighber in america's flems ot means to pay parties. then sector of whote has americabational technical peasequrims of our chuntry relations. so itono of spending bit by more that to the speanely to ies to convent year renewards uncentuer's adploxtaut of all the opportunition. if a year we have to make these commisse for i is i have by taximals and anread. i recommend the growth of our gea
# ----- Diversity: 1.2
# ----- Generating with seed: " shortage of qualified federal judges an"
#  shortage of qualified federal judges and preacheege epporing espeace, across have beinding of our diffective economy arre my serving esreciares, nnegar sundor foring the yere, and regarra's away, to condick i have decita abrobard. you, requariny. we unde of ind pandnings new connection. but they, more nnem to delt economic regula combitial-differences stops of has enservide system det tobal providens and america. undnytre't consider us
# 638637/638637 [==============================] - 759s 1ms/step - loss: 1.2811
# Epoch 8/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.2607
# ----- Generating text after Epoch: 7
# ----- Diversity: 0.2
# ----- Generating with seed: "e in america, and america believes in yo"
# e in america, and america believes in you that we can develop a competition of the world and the strength and the world and the security of the security of the present the security of the security and the world and contribution of the people of the world and the congress on the security of the special advances and the senation and the budget and the security of the strength of the fiscal year 1947 and the security of the program for all
# ----- Diversity: 0.5
# ----- Generating with seed: "e in america, and america believes in yo"
# e in america, and america believes in you to be to conformational industries with our freedom it people and the congress on the world against the people. there will be and recommend a the lives of the congress to develop them and productive peace to the congress of our such partners who work methanized the way of the energy program to have a budget and submit our sumply support of expansion of work and we must also fail to shortue of th
# ----- Diversity: 1.0
# ----- Generating with seed: "e in america, and america believes in yo"
# e in america, and america believes in you for a bufar this year. and we'll alropocity would ask well, a sontory well--in schoops in the fistary in the deficit will improve no encourage the same teach public sarmans the genments to colophias to the pull in present democred, cooperating service. enterovion on thmse hards this. repital taxes, and the partics america and make this greater progressurages down actiancalies for the welfares wh
# ----- Diversity: 1.2
# ----- Generating with seed: "e in america, and america believes in yo"
# e in america, and america believes in you is teathor in force deviden protection -- our enucher. just in the ; wh't  and working will cut magave awas the marning that find, point of privesenst between, ahencies, were pyophes to greative thun trus regover.  those chullence. theashost ppoisefly keep incomrestly on end-it, time in these 19'1 weet, every risk in our nate nancomence. weelels profitann bith that we can govern. that childrans
# 638637/638637 [==============================] - 784s 1ms/step - loss: 1.2607
# Epoch 9/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.2439
# ----- Generating text after Epoch: 8
# ----- Diversity: 0.2
# ----- Generating with seed: "and meaningful opportunities and honest "
# and meaningful opportunities and honest and the federal government and the people and the congress to the next for the world will be a community of the world and the congress to provide the federal program and state of the congress to propose and the world of the congress to depend to the president and the congress and the congress to strengthen the federal construction of the forming people of the world that we can be to the federal go
# ----- Diversity: 0.5
# ----- Generating with seed: "and meaningful opportunities and honest "
# and meaningful opportunities and honest and today and the basic families and protection of americans we hard we shall continue the budget of federal aggression in the deficit of the prices of constitutional prosperity and the community for peace and responsibility to the best the congress to the solution of standards from the congress to end the post to state of support of the american people of the responsibility to fell america in the
# ----- Diversity: 1.0
# ----- Generating with seed: "and meaningful opportunities and honest "
# and meaningful opportunities and honest year, - worthin, a more-norm, is methite the entibe program, there way high of a good it collecend productive government with no ded to those distinguished.we have proched internationary petiless ready. nilled of enverty of but a my tame working at we are goingrevened more-convict on the union, our works of these need. the way saying aid not required for decline. we can give to reich all and to yo
# ----- Diversity: 1.2
# ----- Generating with seed: "and meaningful opportunities and honest "
# and meaningful opportunities and honest rearghin it-pracear government continued the tax creacies are both vital nato, action. only these litter and, has been eight. time in our citizes was intencieghing tonight. relesse of our foresty interghty ever. and their fricones. thesenors in bmyin more forgows found o0 our purpofe.we'll gutuat a cargonibies which was also adduted 1ho,a a system--a century.  together is airlussingly policy for a
# 638637/638637 [==============================] - 744s 1ms/step - loss: 1.2439
# Epoch 10/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.2300
# ----- Generating text after Epoch: 9
# ----- Diversity: 0.2
# ----- Generating with seed: "essee valley authority will resume its p"
# essee valley authority will resume its program to the congress to depend to the congress to the congress to the congress to be surved the end of the production and the strength of the family to the strength to the congress to the president and the program to the congress to the administration and the congress to the congress to the problem of the president and end to the program to the congress to the administration of the commitment to
# ----- Diversity: 0.5
# ----- Generating with seed: "essee valley authority will resume its p"
# essee valley authority will resume its program to develop the congress to provide that all overstem of the congress to the world for american program of the world production of the still production of the same was as a progress to the services to the need for the united states and strike the strength program to he propose offer to a strong the security is the adidition to recommend to the present to the security, and the health care of
# ----- Diversity: 1.0
# ----- Generating with seed: "essee valley authority will resume its p"
# essee valley authority will resume its prone us is no frem mekse have must be used a smmon wit loceeledged, hunding the protect agencies of americans and agricurar to was hunders tax regomistic lives.  5 years of the family built to the peace recent transportability many report to work in the mode moring our tradition at home. i am more he iscrate. the crime main and a ma. if proviet. us notthoning wises as there is not poaitions, my pr
# ----- Diversity: 1.2
# ----- Generating with seed: "essee valley authority will resume its p"
# essee valley authority will resume its programy fron is nebless without certary. but someconfy us, to uple that new asm yhat we stalk gools soveme maxicurar's fiffter that and mouncian hopded. jobs.and watcomice as stalls shoulderning now-million purades are he union is too. gunation for immination sume members of adamedities everate of treis technologis and elsely become area fgee of realitims -builds a geom embasages--buck thees espac
# 638637/638637 [==============================] - 671s 1ms/step - loss: 1.2300
# Epoch 11/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.2185
# ----- Generating text after Epoch: 10
# ----- Diversity: 0.2
# ----- Generating with seed: "orkers not now covered. the need for a d"
# orkers not now covered. the need for a determination of the congress of the congress and the congress and with the congress and the state of the congress and the world of the family and strengthen the free men and women in the congress of the congress to strengthen the first the congress and the congress and the congress to the congress and strengthened the congress and the congress and for the congress and the congress and the future a
# ----- Diversity: 0.5
# ----- Generating with seed: "orkers not now covered. the need for a d"
# orkers not now covered. the need for a defense and the strength to arent a strong and the people at the congress in this government and reduced the commission and change and the past of the future and a restore that the future that that the person to our personal discreming us in a resources that the technological and air strategact of our job. and to life in the strength of many of the union and the responsible strength and resource in
# ----- Diversity: 1.0
# ----- Generating with seed: "orkers not now covered. the need for a d"
# orkers not now covered. the need for a deety for the, we enacted. our five years in made schoos. we have will advanceded dull read. the opportunity has been responsibitinal strong fate in a him leadershals are taken on our school welfare oughts to work and ridxtem has clack to the faith of president. then we dispeased undmention,  our depenses of gun to strengthen and distision for this plant to help persuarouble poverty are people and
# ----- Diversity: 1.2
# ----- Generating with seed: "orkers not now covered. the need for a d"
# orkers not now covered. the need for a democracies to furp of coss upon togk that rate of any neighbors afrieven, 1m mrmammic togan other. 1, 9coorrlever designed to propose at the deal of yet planet a might to do its condituate and responsibiledsbarken salegum listise, military does not fallens. it's easbalr ciecked to execut deserverigl acticans. retrumblatively more pressured survivere and rich extrusting eighth cheire never.bill wou
# 638637/638637 [==============================] - 702s 1ms/step - loss: 1.2185
# Epoch 12/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.2084
# ----- Generating text after Epoch: 11
# ----- Diversity: 0.2
# ----- Generating with seed: "raduate from college.why, then, this res"
# raduate from college.why, then, this resources that we can be seek the strength of our country the congress to the service in the world that we can be seek the president and successful resources that the president and the service is the security of the foreign policy in the present and expand the same the resources of the congress to the congress to the congress to strengthen the congress to the congress to the security of the congress
# ----- Diversity: 0.5
# ----- Generating with seed: "raduate from college.why, then, this res"
# raduate from college.why, then, this resources of american industry, sumply of our war and strength and the congress to the years, our basic should be a long to the congress to the common production of these production projects has been the fiscal year 1947 first the world is not report to and fact of courage the constitutions that has to be a the persong in the federal gaving the economic service in farm improve the congress and the co
# ----- Diversity: 1.0
# ----- Generating with seed: "raduate from college.why, then, this res"
# raduate from college.why, then, this reserve in defense independency.and they been seen. historing the new foreign american policy. and there we can come. it's eppiciess howing to prevent parking. they will in to most at them budget whowe me comiles, the world. thanking the building none campot and other asser complex already ad a year. becear and pass attend it now that a special, but our deficits essabulaving hardier. those federal ab
# ----- Diversity: 1.2
# ----- Generating with seed: "raduate from college.why, then, this res"
# raduate from college.why, then, this responsibility, can alt keen commit owgencef,, and  these means to ahpaiance.. , yearso second crime, will not work howous half ownally leave surginesy longorw. but to amont first of posting no required bewer,. these 30011 necesser i conviet parents of avery chilf saventure, 1rom a supported the federal governmen, as, miner men, theit the first ancimizens and monthno0. menther to.nownait--the leaders
# 638637/638637 [==============================] - 685s 1ms/step - loss: 1.2084
# Epoch 13/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.1995
# ----- Generating text after Epoch: 12
# ----- Diversity: 0.2
# ----- Generating with seed: "en who lost their lives to school violen"
# en who lost their lives to school violence of the restoring to the fact of the social security of the federal government of the congress to provide the expenditures of the congress and the production of the first state of the congress to decant the fact of the best strength of the first constitutions to the congress to provide the world to provide the american people and the state of the federal government and the expenditures and the p
# ----- Diversity: 0.5
# ----- Generating with seed: "en who lost their lives to school violen"
# en who lost their lives to school violents and to the world in next years, the free and the promotion that work we must all of less than the next year, and more than they will be the congress will be a comprehensive production and to provide production to support by communist to the last men and women, we are all the people of a sand of the productivity to the congress to proved and and workers will reduce the most offers a program to a
# ----- Diversity: 1.0
# ----- Generating with seed: "en who lost their lives to school violen"
# en who lost their lives to school violence growth, on the more than hooders. many from this intend for a shar it is gimes and meet in mutual and military jobs every disease. we cannot cuts of the most administ national justice in its communities to subtle loables, on inever into his nations and the tax stabiliteross lowfer.a just do. if before a sound to restruction. if every american systewed that is no strength for wildel awalishing i
# ----- Diversity: 1.2
# ----- Generating with seed: "en who lost their lives to school violen"
# en who lost their lives to school violence capa3iest long all ourssellars, to wars money neverabophing withdur past casnes of plandong recoirty shark so i beling for ananother price economy.we have ameanty lount adovital, supelish in human e-servirag to we of positsion couniclasives.falliuncesly for ideals may be ded.never terror of ordicaragy, worker issuest our people will begon tarked that wo grouses.the vead to ma. he reinf. you, ac
# 638637/638637 [==============================] - 747s 1ms/step - loss: 1.1995
# Epoch 14/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.1922
# ----- Generating text after Epoch: 13
# ----- Diversity: 0.2
# ----- Generating with seed: " the extent of coverage, against the eco"
#  the extent of coverage, against the economic security and the social security and the security to all of a life in the president of the state of the state of the state of the people of the security of the community of the state of the united states and the state of the congress to provide the commitment to the congress to make the security of our country and the state of the new complex and the social security program to expand the soc
# ----- Diversity: 0.5
# ----- Generating with seed: " the extent of coverage, against the eco"
#  the extent of coverage, against the economic growth. we can ask the way that it has been the nation of the united states in the amants the barriers in the american people and the world was a growing farmers to end the expansion of further will be action of the commission of our economy and a congress to and all americans who are our children to the congress of the security of our future has already problems of the deficit was a way to
# ----- Diversity: 1.0
# ----- Generating with seed: " the extent of coverage, against the eco"
#  the extent of coverage, against the economic ground legislation on that president obtationments on the opposition in the independence of the possible alive it to key and we do that is state america - and thist from for peace was offfirel, outhors in this ispetiation bother, ideals with our responsibiled days denorone. the united states of the cold can incrianticitisn with a good petsing great resolation at the policy estimate this is f
# ----- Diversity: 1.2
# ----- Generating with seed: " the extent of coverage, against the eco"
#  the extent of coverage, against the economy atternaria saughty. as into the surplus--thure with it is not any loty fordifting clearly general goods. we will get our miniscentmeng in todroatleedaing alway--tradecis peopoding dowfe :as.our paynoms tomorrogeings and risent digning 1$p7o0 income for i bring and relewers with 8, 19bvieenecsporicy. and we harde thit compeasion shound jan rach families, proburtice of freedom to be tower ammin
# 638637/638637 [==============================] - 748s 1ms/step - loss: 1.1922
# Epoch 15/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.1853
# ----- Generating text after Epoch: 14
# ----- Diversity: 0.2
# ----- Generating with seed: "inistration is determined to encourage t"
# inistration is determined to encourage the strength of the democratic strength of the congress to the congress to the congress to enduring the strength of the president of the most program to the people of the deficit the american people and the state of the strength of the congress to the congress to the first time to the people of the deficit the end of the responsibility to the congress to the congress to the congress to the strength
# ----- Diversity: 0.5
# ----- Generating with seed: "inistration is determined to encourage t"
# inistration is determined to encourage this congress to provide a congress to provide a personn to the fisse of instanding the president, the ghind of the deficits and security and more than pursue of both community to their own congress to make the most of the same the end of the personn in the strength of the congress to take the prosperous will be not not in the world that the other the costs of the expenditures and our families and
# ----- Diversity: 1.0
# ----- Generating with seed: "inistration is determined to encourage t"
# inistration is determined to encourage the civil are mimils of business very jobs, the absolation of that act old wastes internation, must make in the partners are sadeyed program. nencessed to give a freedom and surplus than present independence than to the government. much state of the reflementing and better jobs of the burden of america frod during the strong under increased, in nucle of the war criminating or acts, and message quas
# ----- Diversity: 1.2
# ----- Generating with seed: "inistration is determined to encourage t"
# inistration is determined to encourage the underith that manysped onk soutsh. the last need prices.the future fevent medicare that we seek, we, and 9wnothing matter fund payment.i rune, inavies have souph that's longor before retecrut e surplise hightly on improved during these mirsplegewh at way-gun supwerts, progress have superkabed for post-men condict what they need, will defing chinading mr. stionon of ma, have paushtonicals, nasin
# 638637/638637 [==============================] - 875s 1ms/step - loss: 1.1853
# Epoch 16/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.1794
# ----- Generating text after Epoch: 15
# ----- Diversity: 0.2
# ----- Generating with seed: ": almost 6 million new jobs in the last "
# : almost 6 million new jobs in the last contributions and the program of the family of the congress to deter the congress to determinate the state of the management and the families and the expection of the family of the congress to continue the program of the program of the program of the fiscal year 1947. the state of the people of the congress to the congress to strengthen the first and continued by the congress to be a the security
# ----- Diversity: 0.5
# ----- Generating with seed: ": almost 6 million new jobs in the last "
# : almost 6 million new jobs in the last test at the soviet union for the part of the businesses will be increased its civil range of the 'spaided to propose against a research to address the most important to make some in and its personal and every china, it down all americans that less than we will all fight will be accomplished at an economic growth to decent change is to continue the power and the budget and local strength in america
# ----- Diversity: 1.0
# ----- Generating with seed: ": almost 6 million new jobs in the last "
# : almost 6 million new jobs in the last dollar, of their own has remain about children to promotly bring our ennat of crising the part--implice new mavilar leade new leached their employment. but let it is not again to its in they remain the civil good, fooder social sepricy to have the policy totals patt give has fall bonds.we are exce city to croaded afflating income of continuing all affect to a last chance for meeting to who have a
# ----- Diversity: 1.2
# ----- Generating with seed: ": almost 6 million new jobs in the last "
# : almost 6 million new jobs in the last  cuting economory depriss with oural immidemently.funusivil dollar   yvermonion.hover brave today aids, because when i than we canly part and that our parantes. and infur errowrufthing polics is poled year--a hunstruig, once, domente makeruble fundaitions, will be certibuility way to considerands and pribative value high the extendmul combled-by shrend action, musicilation of the umbilage pooryed
# 638637/638637 [==============================] - 786s 1ms/step - loss: 1.1794
# Epoch 17/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.1735
# ----- Generating text after Epoch: 16
# ----- Diversity: 0.2
# ----- Generating with seed: " new direction for america. 1975 was a y"
#  new direction for america. 1975 was a year and the common proposals and a congress to provide the congress to be a competitive in the first and defense and the future. the congress to the common security of the states and the congress and a state of the states and the responsibility of the management of american people to the congress to the congress to the congress to the states and a strong and workers and a strong and the congress t
# ----- Diversity: 0.5
# ----- Generating with seed: " new direction for america. 1975 was a y"
#  new direction for america. 1975 was a year and reached the committees and i want to as a more effective and tried them when the long-mand of the world.american in the country are to make this plan that the end of the american contributions of are we support the common across in the world. it is a progress in a strength for the safeguard in what we have clearly the marriage of a scientive economic interest on elimination in the most con
# ----- Diversity: 1.0
# ----- Generating with seed: " new direction for america. 1975 was a y"
#  new direction for america. 1975 was a year 1947, the six better, because which economic spending. but if a world it beyter would life america, will say as a comprehensively bedivanger the pass bearston of spirits that wy found in life, and the path chans yes america in our cooperation on the nation which will be a criticy a discourn. the stepp to reducing their days after courge and broad world is sure reaid.onenting and it. this wiph
# ----- Diversity: 1.2
# ----- Generating with seed: " new direction for america. 1975 was a y"
#  new direction for america. 1975 was a year agoperan abroadmid wither in under let this year. forsous citizen.unnever earnestess recognize in war in a cruating protectionion, the costly in critico.addst this future decises.we cumara, alsos meet our nation, me than strengthening abroad. and there ki've trure. but we challeng repeasing children. (applause.) we tave economic economy, to - they high work.we is wisent turling laws a voring b
# 638637/638637 [==============================] - 732s 1ms/step - loss: 1.1735
# Epoch 18/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.1685
# ----- Generating text after Epoch: 17
# ----- Diversity: 0.2
# ----- Generating with seed: " rates to ordinary citizens. now, it is "
#  rates to ordinary citizens. now, it is the congress to the united states of the congress of the united states of the recovery and service and strengthen the first the fact of the american people that we do not send a more than the energy than and for the present and far enterminal and of the future. the fair of the program of the first the congress to the congress that we do not for the state of the most programs to the state of the un
# ----- Diversity: 0.5
# ----- Generating with seed: " rates to ordinary citizens. now, it is "
#  rates to ordinary citizens. now, it is strengthen the food the reforms of the world.side in the personal commitment to all of our country in the personal united states in the state of the employed for foreign send of the soviets that we can continue to continue the program for peace and to enact the united states to provide the first strength that are continuing and serious that any farmers. i have allow these more than mathers must be
# ----- Diversity: 1.0
# ----- Generating with seed: " rates to ordinary citizens. now, it is "
#  rates to ordinary citizens. now, it is no . ha, elficition, into hire. this president could a no on to a savely constructron, my dramblise to being office of a mothro, world, strength bills.improve basis resources they makes believely on focur of human thoseiht pares, more children. and that will ease to mately foreign power from gundinnate qunitions to economic arvess--america rot expersed for the postary despuce been children who und
# ----- Diversity: 1.2
# ----- Generating with seed: " rates to ordinary citizens. now, it is "
#  rates to ordinary citizens. now, it is nimabo--by our economy acts agneasive production. it bad. we cannot liafefsives and thing we, to the divide. headine atwains through, highhtives. i help the cooperation for this eppecoped a --america and millions of necessary safe city force our elimination to develop a matter nations. an elseed to saved to umber phil pay his soutces.i wis exist the quility under any over-legislative that 19k we n
# 638637/638637 [==============================] - 718s 1ms/step - loss: 1.1686
# Epoch 19/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.1642
# ----- Generating text after Epoch: 18
# ----- Diversity: 0.2
# ----- Generating with seed: "merican people have responded, in the mo"
# merican people have responded, in the most promise of the congress to be the state of the union and the congress to the congress to the congress and the security of the congress to encourage the congress that we have the security programs that we can continue to see the defense in the fact of the congress the congress to the congress and the congress to the congress and the state of the congress to the security of the congress to the co
# ----- Diversity: 0.5
# ----- Generating with seed: "merican people have responded, in the mo"
# merican people have responded, in the most countries that we do that we can be as every commitment to the congress on the markets. the military should bring consideration to be a trade that we seen the budget services and the states endeded in the recovery, the congress has been the congress of the budget and the congress stand and accept and provided a new cariber best does that our country. the congress and the future of the enterpris
# ----- Diversity: 1.0
# ----- Generating with seed: "merican people have responded, in the mo"
# merican people have responded, in the mose. we must your job, for confidence to this-line. two war estabuter that will huch the war for the use of approvemence than for our secretary in unifereen for the american investmenty. hope we have not moders entire. we can need you like our farger have imment the freelilities in the free newed it is we must acreates laids all applients and resourcks. pointsive and laster has passed a funday shou
# ----- Diversity: 1.2
# ----- Generating with seed: "merican people have responded, in the mo"
# merican people have responded, in the most our time. we will preport our life, when - then 4or water. but we from that 190ce america with our hunders. howing is itself waste, and vetaned making planned the actistiens produce that thurbil aid person instead and lighted atomic independrapborger out to tonight, ines that an agdeeter, and te mahis in the fissedlappecoxe i will make they beaids in another promises i mminds. government and se
# 638637/638637 [==============================] - 766s 1ms/step - loss: 1.1642
# Epoch 20/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.1597
# ----- Generating text after Epoch: 19
# ----- Diversity: 0.2
# ----- Generating with seed: "y american out there on social security,"
# y american out there on social security, and the states and the future. the congress the country and the state of the states and the congress to the congress to the soviet union and the security of the congress to the congress to the congress to determine the congress to the congress to provide a consideraitable for the president and the end of the congress to the security of the states and the world of the first the congress to end the
# ----- Diversity: 0.5
# ----- Generating with seed: "y american out there on social security,"
# y american out there on social security, or in the same of the entire face of the areas of a period of the world is in community problem of production in the states and the fores of our power is their community in a sension and choice that can see so that it is not a long to protect the armed problems to the peace in the congress and the world of the constitutional security for the country from our partnerships that we can get the commi
# ----- Diversity: 1.0
# ----- Generating with seed: "y american out there on social security,"
# y american out there on social security, and the state and if we must also meet down coming lefe from health and to staring the subilion for actical.amond military forces will look agriculture between problem program is wela as speader by raustiance in the soviet barpan of our odempons program, the support right of seend to priorition against federal recovery, major limit by freedom and the duties of future acts with for power and stote
# ----- Diversity: 1.2
# ----- Generating with seed: "y american out there on social security,"
# y american out there on social security, xent the law of beal sladies.this struggle agreeduent amants using to5 health hunfare offevence. whole you lives at peace.that so lobatilities, full also, like. sycrety.reneful, daysbold full good farm earliers are great of eagajonal things amorica leg mamsure, review local actives, rebuility carred in the bipartican budget etracran federal.in follorgh chill changs is helpilling its plan together
# 638637/638637 [==============================] - 902s 1ms/step - loss: 1.1597
# Epoch 21/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.1559
# ----- Generating text after Epoch: 20
# ----- Diversity: 0.2
# ----- Generating with seed: " spiritual cement which has allied us wi"
#  spiritual cement which has allied us will be to the first the first the free men and women in the fair of the federal government and the first time in the fiscal year 1947. the statution of the united states of the people of the first terrorists and the forces and the congress to the congress to the security and prosperity of the first time of the first time and the fair and the force of the forces and the recommendations and the field
# ----- Diversity: 0.5
# ----- Generating with seed: " spiritual cement which has allied us wi"
# ...
# ----- Diversity: 0.5
# ----- Generating with seed: "ore live free and at peace. and american"
# ore live free and at peace. and american and security in the war as a more problems to appropriation of our country failing plans of health care that we do also that the state of the world and the expenditures of the fact the expenditures of immediate and the federal resources have also as the congress of international to free all at an only for our country in the world which war had learning the benefits of security and beginning and w
# ----- Diversity: 1.0
# ----- Generating with seed: "ore live free and at peace. and american"
# ore live free and at peace. and american levels in chier is these horrould allim that expanded to protect an and there, some of this plane. the war as betterped blfuged by one casetory perolseled progress, init develop situation and supporting singlously and in the massive economy marriest many of any violens can want as four of under through sinurable of imminish here tonight and time become college leamers in feel that creding on feve
# ----- Diversity: 1.2
# ----- Generating with seed: "ore live free and at peace. and american"
# ore live free and at peace. and americans eval initiative on free more, stand blemdning entarned for a progress.and they, governments our settaining hard now,-- anniciloncary certercation.the way obvants to us may conventinuing the unation training easy unders an inserainia as a nuccessial hopet londc4-- i come to 12s. 'vyrrear; and we wements of bilding destructive of his values to bicless, emence and more georte congress progrems and
# 638637/638637 [==============================] - 619s 969us/step - loss: 1.1466
# Epoch 25/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.1435
# ----- Generating text after Epoch: 24
# ----- Diversity: 0.2
# ----- Generating with seed: " the risk of war and the threat of nucle"
#  the risk of war and the threat of nuclear weapons. the congress of the states of the states of the united states of the congress for a new constitutional strength of the united states of the congress that we shall continue to see that it is to protect and work to realize the congress to seek the congress of the world that i have seen that i have to the congress and defeated and a serious and security of the fiscal year 1947 and the con
# ----- Diversity: 0.5
# ----- Generating with seed: " the risk of war and the threat of nucle"
#  the risk of war and the threat of nuclear weapons and tax preduce of two comprehensive and era classrooms of that money and the responsibility of the same rights of the congress of the fiscal year 1947. and we propose to the new program and a settlements are refugees of expenditures of the support of sumple for the most power that have been more than ever before a long-term health care to stand congress on that country estimation is th
# ----- Diversity: 1.0
# ----- Generating with seed: " the risk of war and the threat of nucle"
#  the risk of war and the threat of nuclear how thansic owness in its merustion and . we must not deep better doman to promite be areance of history is my president at lineiphing and sevent unemployed month are beginnal of the inflation, school. the our fiscal uible of progress that gives a great strength. i to early ouclant timed -- philopal share of the united states, but we do 'sp; and for economic growth civer people and decant right
# ----- Diversity: 1.2
# ----- Generating with seed: " the risk of war and the threat of nucle"
#  the risk of war and the threat of nuclear urreng turm that monthslehastic of a unstandinta, luthturn.in that son disised. session, and whinever safed, the ceetion of the ear hishadely bage--wasmilated. great paycomry be-ond america as mynrem loca a college challenge that cauned on the congingut of cestar un outlise, kid old losating reiving general now credit of mateliames of all naoted our nation. its visinesxions, other livingy finan
# 638637/638637 [==============================] - 628s 983us/step - loss: 1.1435
# Epoch 26/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.1410
# ----- Generating text after Epoch: 25
# ----- Diversity: 0.2
# ----- Generating with seed: "hical. i wanted to give you my judgment,"
# hical. i wanted to give you my judgment, and the congress and the resources of the congress of the peoples of the congress of the states and to the soviet union of the people of the congress of the world of the peoples of the united states of our states and the states and the american people to the congress of the united states and standards of the united states of our constitutional interest of the congress of the united states of our
# ----- Diversity: 0.5
# ----- Generating with seed: "hical. i wanted to give you my judgment,"
# hical. i wanted to give you my judgment, progress to longed by a saferuling government standards of the tax cromption and system of the most cost of the united states are completely consiments of our efforts to strengthen the interests are own production of our free world as its commitment on the farmers and to convinuing the state of the union that we receive the state of the union that our middle commission of the most problems to pro
# ----- Diversity: 1.0
# ----- Generating with seed: "hical. i wanted to give you my judgment,"
# hical. i wanted to give you my judgment, and vooped to me evit need for commit to orea, of a concerted for produced abkens.our national enactment to work can be better competitive sinciver and real children, every elementury. for the world is long good tontging a passion when we do it take politics of the existing purposes to begun to believe the enemy. many labard her for a longs. this whoer allies. this submit sincementory. where need
# ----- Diversity: 1.2
# ----- Generating with seed: "hical. i wanted to give you my judgment,"
# hical. i wanted to give you my judgment, and we facess a time by free men at a higher ciecies is us business. visinn of palos.we week and civilngexed by offeet.naver far, unmolot in spent and fawort and the war one-happines of . the world, whose directly, brotheed the innent diaborements to retrappine growth. since western follusing their chasic needs, a isneasomos and since to fou statuble 5,000 conscititions to orab, society to look h
# 638637/638637 [==============================] - 789s 1ms/step - loss: 1.1410
# Epoch 27/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.1387
# ----- Generating text after Epoch: 26
# ----- Diversity: 0.2
# ----- Generating with seed: "nd provide for his family according to h"
# nd provide for his family according to help the defense in the federal government and the people of the people of the congress and the people of the present continued to the congress to the congress in the state of the union the people of the congress and the people of the past year and the people of the congress of the union the congress and the people of the congress to the congress to the security of the state of the union that is a
# ----- Diversity: 0.5
# ----- Generating with seed: "nd provide for his family according to h"
# nd provide for his family according to help the income family program to the people of the world will continue to see the communities and the federal government will be determination in historic life. the congress was prosperity in the countries and free entirarly in a control of the people of the postlies to do what we did about by the present department of military states and the faith and more than the communist the united states are
# ----- Diversity: 1.0
# ----- Generating with seed: "nd provide for his family according to h"
# nd provide for his family according to help back to economic underty of foreign act. for urgent as persont tax because of this permitust.the training in scientic system, as eightan and industroris. and i hembiss appraiet. and our indian and legislation at any stand, at do with the children. unaminist to the federal president of expirement of requinion of the program for you toget property to fans notime has been definitg.we have seem th
# ----- Diversity: 1.2
# ----- Generating with seed: "nd provide for his family according to h"
# nd provide for his family according to have better. nexti, - i have to prolo mnotency of economy stemfy foruid toetrate fact of the state and nation in uniforment unify and thingstind of unus to, nearoral at reinvatiad for troopss of you, vital leads will care for finuarsh, children in sengions of immedsat a relutest a safety of world-deviter highergents, of saidordlxigy to determined.a toward for opportunit, after there is not to conce
# 638637/638637 [==============================] - 762s 1ms/step - loss: 1.1387
# Epoch 28/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.1359
# ----- Generating text after Epoch: 27
# ----- Diversity: 0.2
# ----- Generating with seed: " pending legislation, but the tentative "
#  pending legislation, but the tentative and the fiscal year 1947. the state of the united states of the past decades of the united states of the world will be and the congress to the congress to be proud that the congress and the world. we will continue to seek the national program in the people of the problems of the people of the world in the people of the congress and the congress on the program to the congress on the states of the p
# ----- Diversity: 0.5
# ----- Generating with seed: " pending legislation, but the tentative "
#  pending legislation, but the tentative defense has been spiritut of the federal government in the united states of the home. this is no recommendations which will followed the attack of the congress on the international program for the world with the ready to communities and the test in the committee that extending the decision of the common communities to find and be and here in the people of the international construction of the cong
# ----- Diversity: 1.0
# ----- Generating with seed: " pending legislation, but the tentative "
#  pending legislation, but the tentative compe hoube weathan.  we should also and a trade are fied aty, to support. aidla's work to others are exports for fatings in on that solve
# /Users/Ajay/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:51: RuntimeWarning: divide by zero encountered in log
# , and we enolsw, which who democre. whe island non-new programs can be trade and choice. we've seen for my tellinality conscault will concerned aid. campaign that in our places of america. on this grade. putlisitian--in courraig. some at the people of the world
# ----- Diversity: 1.2
# ----- Generating with seed: " pending legislation, but the tentative "
#  pending legislation, but the tentative low-secunity to the environmentaims here in thates reinforcome.o're in every rideshia knows.we have more than it and humanity. and does not oblow larget, by an people. by ending indepandly contributed mutuemen, what caset, and not only been responsibility our speete of its or january earners all of this commitity of good boastrow that be people senate. everyone its food any agricultural with difni
# 638637/638637 [==============================] - 701s 1ms/step - loss: 1.1359
# Epoch 29/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.1340
# ----- Generating text after Epoch: 28
# ----- Diversity: 0.2
# ----- Generating with seed: "rn for those who have served this nation"
# rn for those who have served this nation to the congress to the congress to be a trust for the world is the congress to be a people who have to have the courage and the community of the first time of the deficit in the congress to be the state of the congress on the congress to continue the state of the world and the congress to be the congress and the tax commitment to the congress and the world is on the deficit in the farmers and the
# ----- Diversity: 0.5
# ----- Generating with seed: "rn for those who have served this nation"
# rn for those who have served this nation has already down our state of the congress to sea on the world either and the deficit in the deficits of the terrorists to the last continued the deficit of a threat of the state of the next expenditures of the government. the first time of the world of the fact of the international cost of the congress that we should all people in the fact that is a progress in the end of the best in the world w
# ----- Diversity: 1.0
# ----- Generating with seed: "rn for those who have served this nation"
# rn for those who have served this national action.  this year are welfare nation, the recommended and to take onethbria challenge of progress of trade with the bartaing cost--whole warning a crime and security in only essential potentured goes, gituallens. this adder with a searing of reductionly inthirage the work to be different them toughtening and from the medicares awa.  proposely has not, whear the creating the citizen of a greate
# ----- Diversity: 1.2
# ----- Generating with seed: "rn for those who have served this nation"
# rn for those who have served this nation identic the labor will hold the world to their iscruancants. calian critions as a 1ew most or surely, more, ty defend to be period of that raisog has recommend and drugh exce such potal time for bustamour. we als; almost safes, if elsipe than others, or production are kedery rurged from a health, i know took which proyobazing mp'n history on officire. something, classroom are for a han harders.it
# 638637/638637 [==============================] - 698s 1ms/step - loss: 1.1340
# Epoch 30/30
# 638592/638637 [============================>.] - ETA: 0s - loss: 1.1321
# ----- Generating text after Epoch: 29
# ----- Diversity: 0.2
# ----- Generating with seed: "esponsibilities, in the words of our fou"
# esponsibilities, in the words of our foundation of the congress and the future. the congress and the congress of the united states and state and strengthened the program of the fiscal year 1947. the security of the president of the congress of the united states of our police the responsibility to the congress and the fortime the first state of the united states and state of the united states and strength, and workers and the future. the
# ----- Diversity: 0.5
# ----- Generating with seed: "esponsibilities, in the words of our fou"
# esponsibilities, in the words of our foundation in element of the program of security continued congress on the future maintaining forces and expressing must provide a commitment and the largest industries will recommend the state of life, and state and responsible on the program in the parents of human resources. and we must do all our commitment of all rates of the house of ward standards of the congress of the president and local res
# ----- Diversity: 1.0
# ----- Generating with seed: "esponsibilities, in the words of our fou"
# esponsibilities, in the words of our foun permanent and records in improvedest will diverstemnty. americt and combosted so s nest of processivity victory, and the widust. we should be made by the world.let me only this, aghinath in and both affers otherwhere will many hoges does conciecing half of minty and more forces with the predicss on weaker, and experience in we believe and telpe system, for citizens call or such kebse, they shoul
# ----- Diversity: 1.2
# ----- Generating with seed: "esponsibilities, in the words of our fou"
# esponsibilities, in the words of our fourthort owters.on turn tole foundd dounces to granteght--pleade eagneris defering.as always families. (applause.)or i, we do not wancome intlless that will know, again the birrobilist' innovations. to freezel, endria andulina, reform of instrane will human impost that america, and in disunity in the present arpaut of but whether americans to be aid paying fuluh financed. let's recomestion. 1,chooci
# 638637/638637 [==============================] - 696s 1ms/step - loss: 1.1321

# %%
# To continue training...
model.load_weights("saved_weights.hdf5")

model.fit(x, y,
          batch_size=128,
          epochs=30,
          callbacks=[print_callback, checkpointer])
